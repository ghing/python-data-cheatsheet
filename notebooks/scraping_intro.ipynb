# %% [markdown]
# # Introduction to scraping in Python

# %% [markdown]
# ## Setup
#
# 1. Download this notebook from <span style="font-size:2em">https://is.gd/MCO510Scraping</span> and put it in the same folder as other notebooks for this class so you can follow along.

# %% [markdown]
# ## Goal
#
# - Build on the concepts from the [Scraping 101](https://docs.google.com/presentation/d/1W4esHT93tKQVUHJLhyVM8f2je-DLWKu-MtzZ7-I6hi8/edit) lecture
# - Think about how to plan and structure a scraping project
# - Learn some skills in Python that can help us start to write scrapers

# %% [markdown]
# ## Assumptions
#
# - Familiarity with HTML
# - Familiarity with CSS selectors
# - This course hasn't really covered Python flow control so far
#
# If this isn't the case it's ok. We'll deal.

# %% [markdown]
# ## Notebook conventions
#
# ### Emoji garden
#
# These are emojis that we'll use in this notebook to draw attention to certain concepts.
#
# ⚠️: Take extra caution or pay extra attention to this!

# %% [markdown]
# ### Identifying cells
#
# We'll start code cells with a comment with a short slug. That way, if anyone has a problem, it's easy to be on the same page about where in the notebook they're working.

# %%
# example-slug

# This cell doesn't do anything, but it shows the convention we'll use for identifying cells.

# %% [markdown]
# ### Javelinas
#
# These are placeholders to hide a solution when you should try some code or think about a question before you read the solution. Experiment, play around with some Python code or collect your thoughts before scolling down.
#
# Now lets scrape some HTML like this javelina is scraping out a place to rest.

# %% [markdown]
# ![](http://www.javelinahunter.com/images/sj2.jpg)

# %% [markdown]
# ## ⚠️ Our first warning: we're scraping a real page
#
# For this tutorial, I decided to talk about scraping a real website which has some structural issues that makes it subtly tricky to scrape. With that in mind, we won't have the satisfaction of ending up with a running scraper, but we will encounter some things that will prepare us for some of the challenges we may find when scraping other sites.

# %% [markdown]
# ## Libraries
#
# This is the reusable code from others that we're bringing into our notebook to help us scrape HTML.
#
# - [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/): Used to parse and extract information from HTML documents.

# %% [markdown]
# Beautiful Soup should already be installed when you installed Anaconda, but we should double check. This command should show information about the version installed.

# %%
# check-bs4-installed

# Check whether the Beautiful Soup package is installed

# !conda list beautifulsoup4
# Out:
# # packages in environment at C:\Users\ghing\anaconda3:
# #
# # Name                    Version                   Build  Channel
# beautifulsoup4            4.10.0             pyh06a4308_0

# %% [markdown]
# If the above command didn't show output, you may have to install the Beautiful Soup package with this command:

# %%
# install-bs4

# If that didn't return output, we'll have to run this to install it

# !conda install -c anaconda beautifulsoup4

# %% [markdown]
# ## Why would we write a scraper in Python?
#
# The skills we're going to go over today are some of the fundamental building blocks for writing a scraper in Python.
#
# But since we're starting out, our pieces of code won't be able to do much more than the tools we already learned about. When  tools like Google Sheets are so powerful, why wouldn't we just use them?

# %% [markdown]
# ![](https://www.arizonahighways.com/sites/default/files/1109_javelina_0.jpg)

# %% [markdown]
# Scrapers written in Python are good for:
#
# - Scale: When you need to scrape hundreds or thousands of pages.
# - Automation: When you need to scrape changing data on the same page regularly
# - Reproducibility: Someone else (or future you) can run your scraper and it should work the same way. Other tools might require writing many grafs in a data diary, or taking a bunch of screenshots to document a process.
# - Learning: If it takes about the same time to write a program as to copy/paste and clean up or manually enter data by hand, maybe it's worth learning something new that can prepare for when tasks are too big to do manually.

# %% [markdown]
# ## "Scraping" is actually a few different steps
#
# - Assess, make a plan
# - Download the content (in many cases, HTML)
# - **Extract elements in the content as structured data.** ⚠️ This is our focus today.
# - Clean and/or transform the data

# %% [markdown]
# ## Why should you break your scraping workflow into these steps?

# %% [markdown]
# ![](https://cdn.branchcms.com/w5pOxEB39B-1533/images/blog/javelina-and-young.jpg)

# %% [markdown]
# - Respect your time!
# - Mix and match strategies: automate the boring, time consuming parts; do the parts that are
# - Have an archive in case the pages go away
# - Let's you test, make changes without having to make a ton of requests

# %% [markdown]
# ## Assess, make a plan
#
# - Do I have to scrape?
#   - Can I file a records request?
#   - Can I just ask for it?
#   - Has someone else done this work?
#     - Academics
#     - Other news orgs
# - How many records are there?
# - Are they split across multiple pages?
# - Can I really get all the data?
# - How long would it take to do manually?
#   - Try timing manually entering one page, or 10 records?
# - Are there any barriers to scraping (CAPTCHA, login, accepting TOS)?
# - Are the URLs predictable?
# - Is the data in the HTML or does it come from an API?
# - Is the request a GET or a POST?
# - Does the format of the data change?
#   - Check to see if the pattern or structure of the data changes by
#     - time period
#     - category
#     - jurisdiction
#   - More differences means more coding and time!

# %% [markdown]
# ## Example: Massage Therapist Search Tool
#
# https://directorymassagetherapy.az.gov/dirsearch/

# %% [markdown]
# ## Download the content
#
# Limitations aside, we'll scrape this data.
#
# We're just going to do this manually for the sake of expedience so we can jump straight into extracting information.
#
# If you wanted to do this with code, try the [requests](https://docs.python-requests.org/en/latest/user/quickstart/#response-content) pacakge.
#
# In your browser's menu: `File` > `Save Page As`
#
# Specify `massage_therapist_results.html` as the file name.
#
# ⚠️ As with other data in notebooks, be sure to save this in the same directory as your notebook. Or, be ready to determine the path to the HTML file in your code.

# %% [markdown]
# ## Open the file in your browser
#
# Use `File` > `Open` in your browser's menu or open a new tab and drag and drop the HTML file, `massage_therapist_results.html` into the tab to open the local copy of the HTML.
#
# ### Then open the developer tools
#
# Right click/ctrl+click somewhere in the data we want to scrape and choose `Inspect` from the context menu to open the developer tools with the `Elements` tab open.
#
# Doing this will help us figure out how to select specific pieces of data with Python code.

# %% [markdown]
# ## Extract elements in the content as structured data

# %% [markdown]
# ### Hello Beautiful Soup
#
# Let's load the downloaded HTML into a `BeautifulSoup` object, which represents the document as a nested data structure.

# %% [markdown]
# First, we have to import the `BeautifulSoup` *class* from the Beautiful Soup *package*, named `bs4`.

# %%
# import-bs4

# Import BeautifulSoup which we'll use to help us scrape information from
# HTML documents.

from bs4 import BeautifulSoup

# %%
# create-path

# Create a path to the HTML file

from pathlib import Path

# You probably want to do this:
results_html_path = Path("massage_therapist_results.html")

# This code is just to make this work on the instructor's computer, which works a little differently.
if not results_html_path.exists():
    results_html_path = Path.cwd() / "data" / "source" / "massage_therapist_results.html"

# %% [markdown]
# Now try to open the HTML file and use it to create an object that represents the nested structure of the document. It's conventional to call the variable for that nested representation `soup`, but this is just a convention. If there's something that makes more sense to you, modify the code to name the variable as you like.
#
# Can anyone describe what this code is doing?

# %%
# create-soup-fail

# Try to load the data into a BeautifulSoup object, which represents
# the document as a nested data structure.
#
# This should produce an error.

with open(results_html_path) as f:
    soup = BeautifulSoup(f, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [4], in <cell line: 8>()
#       1 # create-soup-fail
#       2
#       3 # Try to load the data into a BeautifulSoup object, which represents
#       4 # the document as a nested data structure.
#       5 #
#       6 # This should produce an error.
#       8 with open(results_html_path) as f:
# ----> 9     soup = BeautifulSoup(f, "html.parser")
#
# File ~/.local/share/virtualenvs/python-data-cheatsheet-ujiHmgN_/lib/python3.9/site-packages/bs4/__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309 self.parse_only = parse_only
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312     markup = markup.read()
#     313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#
# File ~/.pyenv/versions/3.9.4/lib/python3.9/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 35789: invalid start byte

# %% [markdown]
# We ran into an error! This is because the file uses an encoding other than the default.
#
# Encodings are a somewhat complicated and annoying concept.
#
# tl;dr: If you get a `UnicodeDecodeError` error when reading a text file, try a different encoding. `latin-1` is common.

# %%
# create-soup

# Try to load the data into a BeautifulSoup object,
# which represents the document as a nested data structure.
# This time, use the right encoding.

with open(results_html_path, encoding="latin-1") as f:
    # Create the BeautifulSoup object.
    # "html.parser" is the parser that Beautiful Soup should use to
    # break the HTML up into a hierarchy that we can traverse and
    # filter. "html.parser" should work well for many cases, but
    # you might want to consider another parser if the HTML
    # is badly formed.
    soup = BeautifulSoup(f, "html.parser")

# %% [markdown]
# Let's look at the HTML.
#
# `soup.prettify()` prints the HTML with nice indendation. Unfortunately, this doesn't help much with this long document. Good thing we have our developer tools!

# %%
# pretty-print-soup

# Pretty print the HTML

print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML+RDFa 1.1//EN">
# <html class="js" dir="ltr" lang="en" version="HTML+RDFa 1.1" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
#  <!-- InstanceBegin template="/Templates/_pages_.dwt.asp" codeOutsideHTMLIsLocked="false" -->
#  <head profile="http://www.w3.org/1999/xhtml/vocab">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script async="" src="./files/ga.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function t(n,e,o){function r(a){if(!e[a]){var i=e[a]={exports:{}};n[a][0].call(i.exports,function(t){var e=n[a][1][t];return r(e?e:t)},i,i.exports,t,n,e,o)}return e[a].exports}for(var a=0;a<o.length;a++)r(o[a]);return r}({D5DuLP:[function(t,n){function e(t,n){var e=o[t];return e?e.apply(this,n):(r[t]||(r[t]=[]),void r[t].push(n))}var o={},r={};n.exports=e,e.queues=r,e.handlers=o},{}],handle:[function(t,n){n.exports=t("D5DuLP")},{}],G9z0Bl:[function(t,n){function e(){var t=d.info=NREUM.info;if(t&&t.agent&&t.licenseKey&&t.applicationID){d.proto="https"===c.split(":")[0]||t.sslForHttp?"https://":"http://",i("mark",["onload",a()]);var n=u.createElement("script");n.src=d.proto+t.agent,u.body.appendChild(n)}}function o(){"complete"===u.readyState&&r()}function r(){i("mark",["domContent",a()])}function a(){return(new Date).getTime()}var i=t("handle"),s=window,u=s.document,p="addEventListener",l="attachEvent",c=(""+location).split("?")[0],d=n.exports={offset:a(),origin:c,features:[]};u[p]?(u[p]("DOMContentLoaded",r,!1),s[p]("load",e,!1)):(u[l]("onreadystatechange",o),s[l]("onload",e)),i("mark",["firstbyte",a()])},{handle:"D5DuLP"}],loader:[function(t,n){n.exports=t("G9z0Bl")},{}]},{},["G9z0Bl"]);
#   </script>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
#   <link href="https://massagetherapy.az.gov/sites/all/themes/moderngov/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <!-- InstanceBeginEditable name="doctitle" -->
#   <title>
#    Massage Therapist Search Tool | Arizona State Board of Massage Therapy
#   </title>
#   <!-- InstanceEndEditable -->
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/modules/system/system.base.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/system/system.menus.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/system/system.messages.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/system/system.theme.css?n452m2");
#   </style>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/misc/ui/jquery.ui.core.css?n452m2");
#         @import url("https://massagetherapy.az.gov/misc/ui/jquery.ui.theme.css?n452m2");
#         @import url("https://massagetherapy.az.gov/misc/ui/jquery.ui.button.css?n452m2");
#         @import url("https://massagetherapy.az.gov/misc/ui/jquery.ui.resizable.css?n452m2");
#         @import url("https://massagetherapy.az.gov/misc/ui/jquery.ui.dialog.css?n452m2");
#   </style>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/comment_notify/comment_notify.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/calendar/css/calendar_multiday.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/comment/comment.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/date/date_api/date.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/date/date_popup/themes/datepicker.1.7.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/date/date_repeat_field/date_repeat_field.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/field/theme/field.css?n452m2");
#   </style>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/modules/node/node.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/search/search.css?n452m2");
#         @import url("https://massagetherapy.az.gov/modules/user/user.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/extlink/extlink.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/views/css/views.css?n452m2");
#   </style>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/colorbox/styles/default/colorbox_style.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/ctools/css/ctools.css?n452m2");
#   </style>
#   <link href="./files/event_calendar_colors.css" media="all" rel="stylesheet" type="text/css"/>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/all/modules/contrib/event_calendar/event_popup/css/event_popup.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/default/files/css/follow.css?n452m2");
#   </style>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/default/files/color/agency_1-d954e8a8/colors.css?n452m2");
#   </style>
#   <style media="all" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/all/themes/omega/alpha/css/alpha-reset.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/alpha/css/alpha-mobile.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/alpha/css/alpha-alpha.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/omega/css/omega-text.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/omega/css/omega-branding.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/omega/css/omega-menu.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/omega/css/omega-visuals.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/global.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/default/files/css_injector/css_injector_1.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/default/files/css_injector/css_injector_4.css?n452m2");
#   </style>
#   <!--[if (lt IE 9)&(!IEMobile)]>
# <style type="text/css" media="all">@import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/agency-1-alpha-default.css?n452m2");
# @import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/agency-1-alpha-default-normal.css?n452m2");
# @import url("https://massagetherapy.az.gov/sites/all/themes/omega/alpha/css/grid/alpha_default/normal/alpha-default-normal-12.css?n452m2");</style>
# <![endif]-->
#   <!--[if gte IE 9]><!-->
#   <style media="all and (min-width: 600px)" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/agency-1-alpha-default.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/agency-1-alpha-default-fluid.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/alpha/css/grid/alpha_default/fluid/alpha-default-fluid-12.css?n452m2");
#   </style>
#   <!--<![endif]-->
#   <!--[if gte IE 9]><!-->
#   <style media="all and (min-width: 980px) and (min-device-width: 980px), all and (max-device-width: 1024px) and (min-width: 1024px) and (orientation:landscape)" type="text/css">
#    @import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/agency-1-alpha-default.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/moderngov/css/agency-1-alpha-default-normal.css?n452m2");
#         @import url("https://massagetherapy.az.gov/sites/all/themes/omega/alpha/css/grid/alpha_default/normal/alpha-default-normal-12.css?n452m2");
#   </style>
#   <!--<![endif]-->
#   <script src="./files/jquery.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.once.js" type="text/javascript">
#   </script>
#   <script src="./files/drupal.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.core.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.widget.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.button.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.mouse.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.draggable.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.position.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.resizable.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.dialog.min.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.ui.dialog.patch.js" type="text/javascript">
#   </script>
#   <script src="./files/comment_notify.js" type="text/javascript">
#   </script>
#   <script src="./files/extlink.js" type="text/javascript">
#   </script>
#   <script src="./files/jquery.colorbox-min.js" type="text/javascript">
#   </script>
#   <script src="./files/colorbox.js" type="text/javascript">
#   </script>
#   <script src="./files/colorbox_style.js" type="text/javascript">
#   </script>
#   <script src="./files/event_popup.js" type="text/javascript">
#   </script>
#   <script src="./files/event_popup_validate.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# window.CKEDITOR_BASEPATH = '/sites/all/libraries/ckeditor/'
# //--><!]]>
#   </script>
#   <script src="./files/omega-mediaqueries.js" type="text/javascript">
#   </script>
#   <script src="./files/omega-equalheights.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"agency_1","theme_token":"uihQH0KQp5PIm8Sxl0dU1t8OgpI2MKZC2EzKDfWbjTo","js":{"misc\/jquery.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"misc\/ui\/jquery.ui.core.min.js":1,"misc\/ui\/jquery.ui.widget.min.js":1,"misc\/ui\/jquery.ui.button.min.js":1,"misc\/ui\/jquery.ui.mouse.min.js":1,"misc\/ui\/jquery.ui.draggable.min.js":1,"misc\/ui\/jquery.ui.position.min.js":1,"misc\/ui\/jquery.ui.resizable.min.js":1,"misc\/ui\/jquery.ui.dialog.min.js":1,"sites\/all\/modules\/contrib\/views\/js\/jquery.ui.dialog.patch.js":1,"sites\/all\/modules\/contrib\/comment_notify\/comment_notify.js":1,"sites\/all\/modules\/contrib\/extlink\/extlink.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/contrib\/event_calendar\/event_popup\/js\/event_popup.js":1,"sites\/all\/modules\/contrib\/event_calendar\/event_popup\/js\/event_popup_validate.js":1,"0":1,"sites\/all\/themes\/omega\/omega\/js\/omega-mediaqueries.js":1,"sites\/all\/themes\/omega\/omega\/js\/omega-equalheights.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.button.css":1,"misc\/ui\/jquery.ui.resizable.css":1,"misc\/ui\/jquery.ui.dialog.css":1,"sites\/all\/modules\/contrib\/comment_notify\/comment_notify.css":1,"sites\/all\/modules\/contrib\/calendar\/css\/calendar_multiday.css":1,"modules\/comment\/comment.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"sites\/all\/modules\/contrib\/date\/date_repeat_field\/date_repeat_field.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/find_content\/find_content.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/extlink\/extlink.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"https:\/\/massagetherapy.az.gov\/\/sites\/default\/filesevent_calendar_colors\/event_calendar_colors.css":1,"sites\/all\/modules\/contrib\/event_calendar\/event_popup\/css\/event_popup.css":1,"sites\/default\/files\/css\/follow.css":1,"sites\/all\/themes\/moderngov\/css\/colors.css":1,"sites\/all\/themes\/omega\/alpha\/css\/alpha-reset.css":1,"sites\/all\/themes\/omega\/alpha\/css\/alpha-mobile.css":1,"sites\/all\/themes\/omega\/alpha\/css\/alpha-alpha.css":1,"sites\/all\/themes\/omega\/omega\/css\/omega-text.css":1,"sites\/all\/themes\/omega\/omega\/css\/omega-branding.css":1,"sites\/all\/themes\/omega\/omega\/css\/omega-menu.css":1,"sites\/all\/themes\/omega\/omega\/css\/omega-visuals.css":1,"sites\/all\/themes\/moderngov\/css\/global.css":1,"public:\/\/css_injector\/css_injector_1.css":1,"public:\/\/css_injector\/css_injector_4.css":1,"ie::normal::sites\/all\/themes\/moderngov\/css\/agency-1-alpha-default.css":1,"ie::normal::sites\/all\/themes\/moderngov\/css\/agency-1-alpha-default-normal.css":1,"ie::normal::sites\/all\/themes\/omega\/alpha\/css\/grid\/alpha_default\/normal\/alpha-default-normal-12.css":1,"fluid::sites\/all\/themes\/moderngov\/css\/agency-1-alpha-default.css":1,"fluid::sites\/all\/themes\/moderngov\/css\/agency-1-alpha-default-fluid.css":1,"sites\/all\/themes\/omega\/alpha\/css\/grid\/alpha_default\/fluid\/alpha-default-fluid-12.css":1,"normal::sites\/all\/themes\/moderngov\/css\/agency-1-alpha-default.css":1,"normal::sites\/all\/themes\/moderngov\/css\/agency-1-alpha-default-normal.css":1,"sites\/all\/themes\/omega\/alpha\/css\/grid\/alpha_def ...
# //--><!]]>
#   </script>
#   <!--[if lt IE 9]><script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script><![endif]-->
#  </head>
#  <body class="html not-front not-logged-in page-for-applicants context-for-applicants omega-mediaqueries-processed omega-equalheights-processed responsive-layout-normal">
#   <div id="omega-media-query-dummy">
#    <style media="all">
#     #omega-media-query-dummy
#             {
#                 position: relative;
#                 z-index: -1;
#             }
#    </style>
#    <!--[if (lt IE 9)&(!IEMobile)]><style media="all">#omega-media-query-dummy { z-index: 1; }</style><![endif]-->
#    <style media="all and (min-width: 600px)">
#     #omega-media-query-dummy
#             {
#                 z-index: 0;
#             }
#    </style>
#    <style media="all and (min-width: 980px) and (min-device-width: 980px), all and (max-device-width: 1024px) and (min-width: 1024px) and (orientation:landscape)">
#     #omega-media-query-dummy
#             {
#                 z-index: 1;
#             }
#    </style>
#   </div>
#   <div id="skip-link">
#    <a class="element-invisible element-focusable" href="https://massagetherapy.az.gov/for-applicants#main-content">
#     Skip to main content
#    </a>
#   </div>
#   <div class="region region-page-top" id="region-page-top">
#    <div class="region-inner region-page-top-inner">
#    </div>
#   </div>
#   <div class="page clearfix" id="page">
#    <script src="./files/sliver.js" type="text/javascript">
#    </script>
#    <link href="./files/sliver.css" media="all" rel="stylesheet" type="text/css"/>
#    <!--<div class="sliver-container"><ul class="sliver-ul"><li class="sliver-li-left"><a href="http://az.gov/agency-directory" target="_blank"><img class="sliver-img" src="./files/icon-agencies.png" title="State Agencies"><span>State Agencies</span></a> </li><li class="sliver-li-left"><a href="http://az.gov/service-directory" target="_blank"><img class="sliver-img" src="./files/icon-services.png" title="State Services"><span>State Services</span></a> </li><li class="sliver-li-right"><a href="http://az.gov/search/" target="_blank"><img class="sliver-img" src="./files/icon-searchlink.png" title="Search AZ.Gov"><span>Search az.gov</span></a><a href="http://az.gov/" target="_blank"><img id="sliver-logo" src="./files/logo-small.png" title="AZ.Gov"></a></li> </ul></div>-->
#    <header class="section section-header" id="section-header">
#     <div class="zone-wrapper zone-branding-wrapper clearfix" id="zone-branding-wrapper">
#      <div class="zone zone-branding clearfix container-12" id="zone-branding">
#       <div class="grid-5 region region-branding" id="region-branding">
#        <div class="region-inner region-branding-inner">
#         <div class="branding-data clearfix">
#          <div class="logo-img">
#           <a href="https://massagetherapy.az.gov/" rel="home" title="Arizona State Board of Massage Therapy">
#            <img alt="Arizona State Board of Massage Therapy" id="logo" src="./files/logo.png"/>
#           </a>
#          </div>
#          <div class="site-name-slogan">
#           <h1 class="site-name">
#            <a href="https://massagetherapy.az.gov/" title="Home">
#             Arizona State Board of Massage Therapy
#            </a>
#           </h1>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="grid-7 region region-menu" id="region-menu">
#        <div class="region-inner region-menu-inner">
#         <nav class="navigation">
#          <div class="block block-search block-form block-search-form odd block-without-title" id="block-search-form">
#           <div class="block-inner clearfix">
#            <div class="content clearfix">
#             <!-- No Search on this Page -->
#            </div>
#           </div>
#          </div>
#          <div class="block block-system block-menu block-main-menu block-system-main-menu even block-without-title" id="block-system-main-menu">
#           <div class="block-inner clearfix">
#            <div class="content clearfix">
#             <ul class="menu clearfix">
#              <li class="first leaf menu-li-home">
#               <a class="menu-home" href="https://massagetherapy.az.gov/" title="">
#                Home
#               </a>
#              </li>
#              <li class="expanded menu-li-about">
#               <a class="menu-about" href="https://massagetherapy.az.gov/about" title="">
#                About
#               </a>
#               <ul class="menu clearfix">
#                <li class="first last leaf menu-li-faq">
#                 <a class="menu-faq" href="https://massagetherapy.az.gov/about/faq">
#                  FAQ
#                 </a>
#                </li>
#                <li class="last leaf menu-li-contact">
#                 <a class="menu-contact" href="https://massagetherapy.az.gov/contact-us" title="">
#                  Contact
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="expanded menu-li-find a therapist">
#               <a class="menu-find a therapist" href="https://massagetherapy.az.gov/find-a-therapist" title="">
#                Find a Therapist
#               </a>
#              </li>
#              <li class="leaf active-trail menu-li-for applicants">
#               <a class="active-trail menu-for applicants active" href="https://massagetherapy.az.gov/for-applicants" title="">
#                For Applicants
#               </a>
#              </li>
#              <li class="leaf menu-li-schools">
#               <a class="menu-schools" href="https://massagetherapy.az.gov/schools">
#                Schools
#               </a>
#              </li>
#              <li class="leaf menu-li-board meetings">
#               <a class="menu-board meetings" href="https://massagetherapy.az.gov/board-meetings" title="">
#                Board Meetings
#               </a>
#              </li>
#              <li class="last leaf menu-li-statutes and rules">
#               <a class="menu-statutes and rules" href="https://massagetherapy.az.gov/statutes-and-rules">
#                Statutes and Rules
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="zone-wrapper zone-header-wrapper clearfix" id="zone-header-wrapper">
#      <div class="zone zone-header clearfix container-12" id="zone-header">
#       <div class="grid-12 region region-header-second" id="region-header-second">
#        <div class="region-inner region-header-second-inner">
#         <div class="block block-delta-blocks block-breadcrumb block-delta-blocks-breadcrumb odd block-without-title" id="block-delta-blocks-breadcrumb">
#          <div class="block-inner clearfix">
#           <div class="content clearfix">
#            <div class="clearfix" id="breadcrumb">
#             <ul class="breadcrumb">
#              <li class="depth-1 odd first">
#               <a href="https://massagetherapy.az.gov/">
#                Home
#               </a>
#              </li>
#              <li class="depth-2 even last">
#               <!-- InstanceBeginEditable name="crumbs" -->
#               <a class="active" href="#">
#                Massage Therapist Search Tool
#               </a>
#               <!-- InstanceEndEditable -->
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <section class="section section-content" id="section-content">
#     <div class="zone-wrapper zone-preface-wrapper clearfix" id="zone-preface-wrapper">
#      <div class="zone zone-preface clearfix container-12" id="zone-preface">
#       <div class="grid-4 region region-preface-first" id="region-preface-first">
#        <div class="region-inner region-preface-first-inner">
#         <section class="block block-views block-preface-views-block-3 block-views-preface-views-block-3 odd" id="block-views-preface-views-block-3">
#          <div class="block-inner clearfix">
#           <h2 class="block-title">
#            Directory
#           </h2>
#           <div class="content clearfix">
#            <div class="view view-preface-views view-id-preface_views view-display-id-block_3 view-dom-id-2d243917ce47b771f00f1eb6f3632817">
#             <div class="view-content">
#              <div class="views-row views-row-1 views-row-odd views-row-first views-row-last clearfix">
#               <div class="views-field views-field-title">
#                <span class="field-content">
#                 Find a Massage Therapist and Disciplinary Actions
#                </span>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <p>
#                  To find a Massage Therapist, use the Massage Therapist Search Tool. Click on search, then use...
#                 </p>
#                </div>
#               </div>
#               <div class="views-field views-field-nothing read-more views-field-view-node">
#                <span class="field-content">
#                 <a href="https://massagetherapy.az.gov/find-a-therapist">
#                  Read More
#                 </a>
#                </span>
#               </div>
#               <div class="views-field views-field-edit-node">
#                <span class="field-content">
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="grid-4 region region-preface-second" id="region-preface-second">
#        <div class="region-inner region-preface-second-inner">
#         <section class="block block-views block-preface-views-block-2 block-views-preface-views-block-2 odd" id="block-views-preface-views-block-2">
#          <div class="block-inner clearfix">
#           <h2 class="block-title">
#            Obtaining a License
#           </h2>
#           <div class="content clearfix">
#            <div class="view view-preface-views view-id-preface_views view-display-id-block_2 view-dom-id-effc01ed40521fdac945b5314cb12fb7">
#             <div class="view-content">
#              <div class="views-row views-row-1 views-row-odd views-row-first views-row-last clearfix">
#               <div class="views-field views-field-title">
#                <span class="field-content">
#                 Initial Application and Renewal
#                </span>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <p>
#                  If you are applying for a Massage Therapy License in Arizona or if you are Renewing, click on...
#                 </p>
#                </div>
#               </div>
#               <div class="views-field views-field-nothing read-more views-field-view-node">
#                <span class="field-content">
#                 <a href="https://massagetherapy.az.gov/for-applicants">
#                  Read More
#                 </a>
#                </span>
#               </div>
#               <div class="views-field views-field-edit-node">
#                <span class="field-content">
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="grid-4 region region-preface-third" id="region-preface-third">
#        <div class="region-inner region-preface-third-inner">
#         <section class="block block-views block-preface-views-block-1 block-views-preface-views-block-1 odd" id="block-views-preface-views-block-1">
#          <div class="block-inner clearfix">
#           <h2 class="block-title">
#            File a Complaint
#           </h2>
#           <div class="content clearfix">
#            <div class="view view-preface-views view-id-preface_views view-display-id-block_1 view-dom-id-4f5bad9f809b6857c846fbb24eb1b90a">
#             <div class="view-content">
#              <div class="views-row views-row-1 views-row-odd views-row-first views-row-last clearfix">
#               <div class="views-field views-field-title">
#                <span class="field-content">
#                 Complaint Form
#                </span>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <p>
#                  Anyone claiming to have been harmed by a massage therapist in Arizona may file a complaint...
#                 </p>
#                </div>
#               </div>
#               <div class="views-field views-field-nothing read-more views-field-view-node">
#                <span class="field-content">
#                 <a href="https://massagetherapy.az.gov/complaint-form">
#                  Read More
#                 </a>
#                </span>
#               </div>
#               <div class="views-field views-field-edit-node">
#                <span class="field-content">
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="zone-wrapper zone-content-wrapper clearfix" id="zone-content-wrapper">
#      <div class="zone zone-content clearfix container-12" id="zone-content">
#       <div class="grid-8 region region-content" id="region-content">
#        <div class="region-inner region-content-inner">
#         <a id="main-content">
#         </a>
#         <!-- InstanceBeginEditable name="body" -->
#         <h1 class="title" id="page-title">
#          Massage Therapist Search Tool
#         </h1>
#         <div class="block block-system block-main block-system-main odd block-without-title" id="block-system-main">
#          <div class="block-inner clearfix">
#           <div class="content clearfix">
#            <div class="view view-for-applicants view-id-for_applicants view-display-id-page view-dom-id-16de189b0811c551ffebe5f8e39ea2f3">
#             <!-- start content -->
#             <div class="view-content">
#              <div class="views-row views-row-1 views-row-odd views-row-first clearfix">
#               <div class="views-field views-field-title">
#                <center>
#                 <table bgcolor="#DCE4F1" border="1" bordercolor="#456198" cellpadding="0" cellspacing="0" width="390">
#                  <tr>
#                   <td align="center">
#                    <form action="" method="get">
#                     <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                      <strong>
#                       Customize This
#                     Listing
#                      </strong>
#                     </font>
#                     <table bgcolor="#DCE4F1" border="0" cellpadding="4" cellspacing="0" width="378">
#                      <tr>
#                       <td align="right" nowrap="nowrap">
#                        <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         Search
#                         <select name="searchField">
#                          <option value="webNone">
#                           Non-Specified
#                          </option>
#                          <option selected="" value="webLastName">
#                           Last Name
#                          </option>
#                          <option value="webFirstName">
#                           First Name
#                          </option>
#                          <option value="webAddress">
#                           Address
#                          </option>
#                          <option value="webCityStateZip">
#                           City, State ZIP
#                          </option>
#                          <option value="webCrtLicenseNumber">
#                           License Number
#                          </option>
#                          <option value="webCstStatusName">
#                           License Status
#                          </option>
#                         </select>
#                         <br/>
#                         <input name="pageNo" type="hidden" value="1"/>
#                        </font>
#                       </td>
#                       <td align="right" nowrap="nowrap">
#                        <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         FOR
#                         <input maxlength="50" name="searchString" size="20" type="text" value="A"/>
#                        </font>
#                       </td>
#                      </tr>
#                      <tr>
#                       <td align="right" nowrap="nowrap">
#                        <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         Sort On
#                         <select name="orderBy1">
#                          <option selected="" value="webNone">
#                           Non-Specified
#                          </option>
#                          <option value="webLastName">
#                           Last Name
#                          </option>
#                          <option value="webFirstName">
#                           First Name
#                          </option>
#                          <option value="webAddress">
#                           Address
#                          </option>
#                          <option value="webCityStateZip">
#                           City, State ZIP
#                          </option>
#                          <option value="webCrtLicenseNumber">
#                           License Number
#                          </option>
#                          <option value="webCstStatusName">
#                           License Status
#                          </option>
#                         </select>
#                        </font>
#                       </td>
#                       <td align="left" nowrap="nowrap">
#                        <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         AND
#                         <select name="orderBy2">
#                          <option selected="" value="webNone">
#                           Non-Specified
#                          </option>
#                          <option value="webLastName">
#                           Last Name
#                          </option>
#                          <option value="webFirstName">
#                           First Name
#                          </option>
#                          <option value="webAddress">
#                           Address
#                          </option>
#                          <option value="webCityStateZip">
#                           City, State ZIP
#                          </option>
#                          <option value="webCrtLicenseNumber">
#                           License Number
#                          </option>
#                          <option value="webCstStatusName">
#                           License Status
#                          </option>
#                         </select>
#                        </font>
#                       </td>
#                      </tr>
#                      <tr>
#                       <td align="center" colspan="2">
#                        <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         Records Per Page:
#                         <input maxlength="3" name="recsPerPage" size="3" type="text" value="20"/>
#                         Zero lists all records
#                        </font>
#                       </td>
#                      </tr>
#                     </table>
#                     <input name="Submit" type="submit" value="Refresh Data"/>
#                    </form>
#                   </td>
#                  </tr>
#                 </table>
#                </center>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <div>
#                  <br/>
#                  <br/>
#                  <center>
#                   <table bgcolor="#ACC0EA" border="1" bordercolor="#456198" cellpadding="0" cellspacing="0" width="390">
#                    <tr>
#                     <td align="center">
#                      <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                       <strong>
#                        Directory Results
#                       </strong>
#                      </font>
#                      <table bgcolor="#DCE4F1" border="0" cellpadding="4" cellspacing="0" width="378">
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Ciuffardi,
#                                         Diana
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Active
#                                          #MT-26872
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          6420 S Camino Dela Tierra #1305
#                          <br/>
#                          Tucson, AZ 85746
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 4/2/2020
#                          <br/>
#                          Expires: 1/29/2023
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Esparza,
#                                         Rosie
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Closed  App. Withdrawn
#                                          #N/A
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          4322 N 13th PL @102
#                          <br/>
#                          Phoenix, AZ 85014
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued:
#                          <br/>
#                          Expires:
#                          <br/>
#                          <!--Status:&nbsp;-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Giessman,
#                                         Marina
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Active
#                                          #MT-26969
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          1632 South Santa Belia
#                          <br/>
#                          Green Valley, AZ 85614
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 7/2/2020
#                          <br/>
#                          Expires: 10/29/2022
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Han,
#                                         Katherine
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Active
#                                          #MT-28071
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          4220 Kissena Blvd F7
#                          <br/>
#                          Flushing, NY 11355
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 11/19/2021
#                          <br/>
#                          Expires: 10/26/2024
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Malaela,
#                                         Karalee
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Active
#                                          #MT-21228
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          2218 E. Williamsfield Rd.
#                          <br/>
#                          Gilbert, AZ 85295
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 5/5/2015
#                          <br/>
#                          Expires: 1/25/2024
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Sherman,
#                                         Adrea
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Closed  Expired
#                                          #MT-21525
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          1631 E Don Carlos Ave #103
#                          <br/>
#                          Tempe, AZ 85281
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 7/30/2015
#                          <br/>
#                          Expires: 10/4/2017
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#DCE4F1">
# ...
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 9/8/2020
#                          <br/>
#                          Expires: 12/20/2022
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Abarca,
#                                         Ricardo
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Closed  Expired
#                                          #MT-16760
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          6039 S 12th St
#                          <br/>
#                          Phoenix, AZ 85042
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 12/14/2011
#                          <br/>
#                          Expires: 10/3/2014
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Abate,
#                                         Stephen
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Active
#                                          #MT-27557
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          14021 Villa Sandia PL NE
#                          <br/>
#                          Albuquerque, NM 87112
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 3/31/2021
#                          <br/>
#                          Expires: 4/4/2023
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#DCE4F1" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td bgcolor="#456198" colspan="2" height="1">
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="left" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          <strong>
#                           Abbate,
#                                         Melissa
#                          </strong>
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Active
#                                          #MT-14126
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          3510 East Hampton Avenue UNIT 20
#                          <br/>
#                          Mesa, AZ 85204
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                          Issued: 4/9/2010
#                          <br/>
#                          Expires: 4/24/2022
#                          <br/>
#                          <!--Status:&nbsp;Approved-->
#                         </font>
#                        </td>
#                       </tr>
#                       <tr>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                        <td align="right" bgcolor="#F7F9FD" valign="top">
#                         <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#                         </font>
#                        </td>
#                       </tr>
#                      </table>
#                      <input name="Submit" type="submit" value="Next &gt;&gt;"/>
#                     </td>
#                    </tr>
#                   </table>
#                  </center>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <!-- end content -->
#            </div>
#           </div>
#          </div>
#         </div>
#         <!-- InstanceEndEditable -->
#        </div>
#       </div>
#       <aside class="grid-4 region region-sidebar-second" id="region-sidebar-second">
#        <div class="region-inner region-sidebar-second-inner">
#         <div class="block block-views block-random-images-block block-views-random-images-block odd block-without-title" id="block-views-random-images-block">
#          <div class="block-inner clearfix">
#           <div class="content clearfix">
#            <div class="view view-random-images view-id-random_images view-display-id-block view-dom-id-196259daf5b181c40926cccbdeb5a8d0">
#             <div class="view-header">
#              <br/>
#             </div>
#             <div class="view-content">
#              <div class="views-row views-row-1 views-row-odd views-row-first views-row-last clearfix">
#               <div class="views-field views-field-field-photo-image">
#                <div class="field-content">
#                 <img alt="Random Image" height="120" src="./files/pic4.jpg" title="Random Image" typeof="foaf:Image" width="160"/>
#                </div>
#               </div>
#               <div class="views-field views-field-edit-node">
#                <span class="field-content">
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </aside>
#      </div>
#     </div>
#    </section>
#    <footer class="section section-footer" id="section-footer">
#     <div class="zone-wrapper zone-footer-wrapper clearfix" id="zone-footer-wrapper">
#      <div class="zone zone-footer clearfix container-12" id="zone-footer">
#       <div class="grid-12 region region-footer-first" id="region-footer-first">
#        <div class="region-inner region-footer-first-inner">
#         <div id="footer-expand" style="clear:both;">
#          <nav class="footer-nav clearfix" id="footer-nav" style="margin: 0px; padding: 0px;">
#           <section class="clearfix" id="footer-info">
#            <div class="footer-branding clearfix">
#             <div id="footer-logo">
#              <img class="footer-logo-image" src="./files/logo.png"/>
#             </div>
#             <div class="footer-site-name-slogan">
#              <div class="footer-site-name">
#               Arizona State Board of Massage Therapy
#              </div>
#             </div>
#            </div>
#            <section class="block block-nodeblock block-contact-us block-nodeblock-contact-us odd" id="block-nodeblock-contact-us">
#             <div class="block-inner clearfix">
#              <h2 class="block-title">
#               <a href="https://massagetherapy.az.gov/contact-us">
#                Contact Us
#               </a>
#              </h2>
#              <div class="content clearfix">
#               <div class="node node-promoted node-agency-contact-card node-published node-not-sticky odd clearfix" id="node-agency-contact-card">
#                <div class="content clearfix">
#                 <div class="field-group-format group_address field-group-div group-address speed-fast effect-none">
#                  <div class="field-group-format group_column1 field-group-div group-column1 speed-fast effect-none">
#                   <div class="field field-name-field-address-name field-type-text field-label-hidden">
#                    <div class="field-items">
#                     <div class="field-item even">
#                      Board of Massage Therapy
#                     </div>
#                    </div>
#                   </div>
#                   <div class="field field-name-field-address- field-type-text field-label-hidden">
#                    <div class="field-items">
#                     <div class="field-item even">
#                      1740 West Adams Street, Suite #3401
#                     </div>
#                    </div>
#                   </div>
#                   <div class="field field-name-field-address-line-2 field-type-text field-label-hidden">
#                    <div class="field-items">
#                     <div class="field-item even">
#                      Phoenix, AZ 85007
#                     </div>
#                    </div>
#                   </div>
#                   <div class="field field-name-field-google-maps-link field-type-link-field field-label-hidden">
#                    <div class="field-items">
#                     <div class="field-item even">
#                      <a href="https://www.google.com/maps/place/1400+W+Washington+St/@33.448514,-112.090909,17z" target="_blank">
#                       View in Google Maps
#                      </a>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="field-group-format field-group-div group_column2 speed-fast effect-none">
#                   <div class="field field-name-field-phone-number field-type-text field-label-inline clearfix">
#                    <div class="field-label">
#                     phone:
#                    </div>
#                    <div class="field-items">
#                     <div class="field-item even">
#                      (602) 542-8604
#                      <br/>
#                      <strong>
#                       complaints:
#                      </strong>
#                      <br/>
#                      (602) 542-8225
#                     </div>
#                    </div>
#                   </div>
#                   <div class="field field-name-field-fax field-type-text field-label-inline clearfix">
#                    <div class="field-label">
#                     fax:
#                    </div>
#                    <div class="field-items">
#                     <div class="field-item even">
#                      (602) 542-8804
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="field field-name-field-map-image field-type-image field-label-hidden">
#                  <!--<div class="field-items">
#                   <div class="field-item even"><a href="https://www.google.com/maps/place/1400+W+Washington+St/@33.448514,-112.090909,17z" target="_blank"><img src="//massagetherapy.az.gov/sites/default/files/background_images" alt=""></a></div>
#                 </div> -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#           </section>
#           <!--section id="footer-menu" class="clearfix">
#           <div class="footer-menu-wrapper">
#             <div id="footer-nav-wrapper">
#                           </div>
#             <div id="follow-wrapper">
#                           </div>
#             <br class="clearfix" />
#           </div>
#         </section-->
#          </nav>
#         </div>
#        </div>
#       </div>
#       <div class="grid-12 region region-footer-second" id="region-footer-second">
#        <div class="region-inner region-footer-second-inner">
#         <section class="block block-menu block-menu-footer-utility block-menu-menu-footer-utility odd" id="block-menu-menu-footer-utility">
#          <div class="block-inner clearfix">
#           <h2 class="block-title">
#            Footer Utility
#           </h2>
#           <div class="content clearfix">
#            <ul class="menu clearfix">
#             <li class="first leaf menu-li-statewide policies">
#              <a class="menu-statewide policies" href="https://az.gov/policies" target="_blank" title="Statewide Policies">
#               Statewide Policies
#              </a>
#             </li>
#             <li class="last leaf menu-li-site map">
#              <a class="menu-site map" href="https://massagetherapy.az.gov/sitemap" title="Site Map">
#               Site Map
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <div class="region region-page-bottom" id="region-page-bottom">
#    <div class="region-inner region-page-bottom-inner">
#    </div>
#   </div>
#  </body>
#  <!-- InstanceEnd -->
# </html>

# %% [markdown]
# ## CSS selectors
#
# Beautiful Soup has its own method of [navigating](https://beautiful-soup-4.readthedocs.io/en/latest/index.html?highlight=select#navigating-the-tree) and [searching](https://beautiful-soup-4.readthedocs.io/en/latest/index.html?highlight=select#searching-the-tree) the HTML document.
#
# However, we're going to use [CSS selectors](https://beautiful-soup-4.readthedocs.io/en/latest/index.html?highlight=select#css-selectors) to specify elements. This is for a few reasons:
#
# - Maybe you already know a little CSS. Or, learning it can be helpful for visualizing data or making web pages/apps.
# - Browser developer tools can tell us the selector for a particular element

# %% [markdown]
# ### `soup.select_one()` gets one element
#
# If there is more than one matching element, it returns the first one. The value returned by the `select_one()` method is a `Tag`.

# %%
# get-first-graf

# Get the first paragraph on the page

first_graf = soup.select_one("p")

type(first_graf)
# Out:
# bs4.element.Tag

# %% [markdown]
# Using a `Tag` object like you would a string prints the HTML of the element.

# %%
# display-first-graf

# Display the HTML of the first paragraph element.

first_graf
# Out:
# <p>To find a Massage Therapist, use the Massage Therapist Search Tool. Click on search, then use...</p>

# %% [markdown]
# ### `soup.select()` returns all matching elements as a list

# %%
# get-all-grafs

# Get and display all the paragraphs on the page

all_grafs = soup.select("p")

all_grafs
# Out:
# [<p>To find a Massage Therapist, use the Massage Therapist Search Tool. Click on search, then use...</p>,
#  <p>If you are applying for a Massage Therapy License in Arizona or if you are Renewing, click on...</p>,
#  <p>Anyone claiming to have been harmed by a massage therapist in Arizona may file a complaint...</p>]

# %% [markdown]
# We can use our browser developer tools to help find the CSS selector for a particular element.
#
# In the `Elements` tab of developer tools, right/ctrl+click on a particular element and choose `Copy` > `Copy selector` from the context menu.
#
# Try to use `soup.select_one()` and the selector copied from the developer tools to get the *outer* table that contains the list of massage therapists.

# %%
# select-table-entry

# Get the table element for the data that we want to scrape

table = soup.select_one(".replace-this-with-your-selector")

table

# %% [markdown]
# ![](https://www.gannett-cdn.com/-mm-/9d39186ff6bbd045462cf0211336ac42a105219b/c=0-11-271-164/local/-/media/2018/03/22/Phoenix/Phoenix/636573333519944047-javelina2.PNG?auto=webp&format=pjpg&width=1200)

# %%
# select-table

# Get the table element for the data that we want to scrape

# If you used your browser's developer tools, it might look something like this:
table = soup.select_one("#block-system-main > div > div > div > div > div > div.views-field.views-field-body > div > div > center > table")

# If you get stuck, type this simpler selector
#table = soup.select_one(".views-field.views-field-body table")

print(table.prettify())
# Out:
# <table bgcolor="#ACC0EA" border="1" bordercolor="#456198" cellpadding="0" cellspacing="0" width="390">
#  <tr>
#   <td align="center">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Directory Results
#     </strong>
#    </font>
#    <table bgcolor="#DCE4F1" border="0" cellpadding="4" cellspacing="0" width="378">
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Ciuffardi,
#                                         Diana
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-26872
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        6420 S Camino Dela Tierra #1305
#        <br/>
#        Tucson, AZ 85746
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 4/2/2020
#        <br/>
#        Expires: 1/29/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Esparza,
#                                         Rosie
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Closed  App. Withdrawn
#                                          #N/A
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        4322 N 13th PL @102
#        <br/>
#        Phoenix, AZ 85014
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued:
#        <br/>
#        Expires:
#        <br/>
#        <!--Status:&nbsp;-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Giessman,
#                                         Marina
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-26969
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        1632 South Santa Belia
#        <br/>
#        Green Valley, AZ 85614
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 7/2/2020
#        <br/>
#        Expires: 10/29/2022
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Han,
#                                         Katherine
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-28071
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        4220 Kissena Blvd F7
#        <br/>
#        Flushing, NY 11355
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 11/19/2021
#        <br/>
#        Expires: 10/26/2024
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Malaela,
#                                         Karalee
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-21228
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        2218 E. Williamsfield Rd.
#        <br/>
#        Gilbert, AZ 85295
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 5/5/2015
#        <br/>
#        Expires: 1/25/2024
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Sherman,
#                                         Adrea
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Closed  Expired
#                                          #MT-21525
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        1631 E Don Carlos Ave #103
#        <br/>
#        Tempe, AZ 85281
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 7/30/2015
#        <br/>
#        Expires: 10/4/2017
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Tovar,
#                                         Emily
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-27882
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        1117 N Palo Verde St
#        <br/>
#        Eloy, AZ 85131
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 8/8/2021
#        <br/>
#        Expires: 10/7/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Urvanejo,
#                                         Ana
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-27625
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        2219 E Dortha Ave #7
#        <br/>
#        Flagstaff, AZ 86004
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 5/9/2021
#        <br/>
#        Expires: 9/28/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Walker,
#                                         Michele
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-27884
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        PO Box 97511
#        <br/>
#        Phoenix, AZ 85060
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 8/8/2021
#        <br/>
#        Expires: 2/1/2024
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Watkins,
#                                         Judith
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-27966
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        7151 W Indian School Rd #2076
#        <br/>
#        Phoenix, AZ 85033
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 9/17/2021
#        <br/>
#        Expires: 9/30/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Aaron,
#                                         Cassandra
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-14475
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        9800 Talking Stick Way
#        <br/>
#        Scottsdale, AZ 85256
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 7/1/2010
#        <br/>
#        Expires: 10/29/2022
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Aaron,
#                                         Lori
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Closed  Expired
#                                          #MT-05049
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        4121 E Ashurst Dr
#        <br/>
#        Phoenix, AZ 85048
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 4/12/2005
#        <br/>
#        Expires: 1/16/2010
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abad,
#                                         Cheryl
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-02035P
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        26831 N. 54th Lane
#        <br/>
#        Phoenix, AZ 85083
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 12/6/2004
#        <br/>
#        Expires: 9/1/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abagat,
#                                         Alicia
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Closed  Expired
#                                          #MT-10334
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        44960 W Sandhill Rd
#        <br/>
#        Maricopa, AZ 85239
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 10/25/2007
#        <br/>
#        Expires: 11/28/2009
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abarca,
#                                         Adriana
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Closed  Expired
#                                          #MT-04249P
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        17031 N 11th Ave #2147
#        <br/>
#        Phoenix, AZ 85023
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 2/15/2005
#        <br/>
#        Expires: 8/25/2007
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abarca,
#                                         Jessica
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-15828
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        9557 W Quail ave
#        <br/>
#        Peoria, AZ 85382
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 6/13/2011
#        <br/>
#        Expires: 11/10/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abarca,
#                                         Maria
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-27094
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        6141 S Park Ave Unit 4
#        <br/>
#        Tucson, AZ 85706
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 9/8/2020
#        <br/>
#        Expires: 12/20/2022
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abarca,
#                                         Ricardo
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Closed  Expired
#                                          #MT-16760
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        6039 S 12th St
#        <br/>
#        Phoenix, AZ 85042
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 12/14/2011
#        <br/>
#        Expires: 10/3/2014
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abate,
#                                         Stephen
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-27557
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        14021 Villa Sandia PL NE
#        <br/>
#        Albuquerque, NM 87112
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 3/31/2021
#        <br/>
#        Expires: 4/4/2023
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#DCE4F1" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#456198" colspan="2" height="1">
#      </td>
#     </tr>
#     <tr>
#      <td align="left" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        <strong>
#         Abbate,
#                                         Melissa
#        </strong>
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Active
#                                          #MT-14126
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        3510 East Hampton Avenue UNIT 20
#        <br/>
#        Mesa, AZ 85204
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#        Issued: 4/9/2010
#        <br/>
#        Expires: 4/24/2022
#        <br/>
#        <!--Status:&nbsp;Approved-->
#       </font>
#      </td>
#     </tr>
#     <tr>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#      <td align="right" bgcolor="#F7F9FD" valign="top">
#       <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#       </font>
#      </td>
#     </tr>
#    </table>
#    <input name="Submit" type="submit" value="Next &gt;&gt;"/>
#   </td>
#  </tr>
# </table>

# %% [markdown]
# ### Tag elements have `select()` and `select_one()` methods too

# %% [markdown]
# You may have noticed that there's a table inside a table. We can call `select_one()` on the table object we just grabbed to get the innermost table. In this case, the selector will be relative to the parent element. Also, we can no longer just copy and paste the selector from the browser developer tools, but working on a branch of the big HTML tree makes the selectors easier to figure out.

# %%
# select-inner-table

# Get the inner-most table

inner_table = table.select_one("table")

print(inner_table.prettify())
# Out:
# <table bgcolor="#DCE4F1" border="0" cellpadding="4" cellspacing="0" width="378">
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Ciuffardi,
#                                         Diana
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-26872
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     6420 S Camino Dela Tierra #1305
#     <br/>
#     Tucson, AZ 85746
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 4/2/2020
#     <br/>
#     Expires: 1/29/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Esparza,
#                                         Rosie
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Closed  App. Withdrawn
#                                          #N/A
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     4322 N 13th PL @102
#     <br/>
#     Phoenix, AZ 85014
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued:
#     <br/>
#     Expires:
#     <br/>
#     <!--Status:&nbsp;-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Giessman,
#                                         Marina
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-26969
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     1632 South Santa Belia
#     <br/>
#     Green Valley, AZ 85614
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 7/2/2020
#     <br/>
#     Expires: 10/29/2022
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Han,
#                                         Katherine
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-28071
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     4220 Kissena Blvd F7
#     <br/>
#     Flushing, NY 11355
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 11/19/2021
#     <br/>
#     Expires: 10/26/2024
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Malaela,
#                                         Karalee
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-21228
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     2218 E. Williamsfield Rd.
#     <br/>
#     Gilbert, AZ 85295
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 5/5/2015
#     <br/>
#     Expires: 1/25/2024
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Sherman,
#                                         Adrea
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Closed  Expired
#                                          #MT-21525
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     1631 E Don Carlos Ave #103
#     <br/>
#     Tempe, AZ 85281
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 7/30/2015
#     <br/>
#     Expires: 10/4/2017
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Tovar,
#                                         Emily
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-27882
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     1117 N Palo Verde St
#     <br/>
#     Eloy, AZ 85131
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 8/8/2021
#     <br/>
#     Expires: 10/7/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Urvanejo,
#                                         Ana
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-27625
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     2219 E Dortha Ave #7
#     <br/>
#     Flagstaff, AZ 86004
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 5/9/2021
#     <br/>
#     Expires: 9/28/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Walker,
#                                         Michele
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-27884
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     PO Box 97511
#     <br/>
#     Phoenix, AZ 85060
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 8/8/2021
#     <br/>
#     Expires: 2/1/2024
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Watkins,
#                                         Judith
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-27966
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     7151 W Indian School Rd #2076
#     <br/>
#     Phoenix, AZ 85033
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 9/17/2021
#     <br/>
#     Expires: 9/30/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Aaron,
#                                         Cassandra
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-14475
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     9800 Talking Stick Way
#     <br/>
#     Scottsdale, AZ 85256
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 7/1/2010
#     <br/>
#     Expires: 10/29/2022
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Aaron,
#                                         Lori
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Closed  Expired
#                                          #MT-05049
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     4121 E Ashurst Dr
#     <br/>
#     Phoenix, AZ 85048
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 4/12/2005
#     <br/>
#     Expires: 1/16/2010
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abad,
#                                         Cheryl
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-02035P
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     26831 N. 54th Lane
#     <br/>
#     Phoenix, AZ 85083
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 12/6/2004
#     <br/>
#     Expires: 9/1/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abagat,
#                                         Alicia
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Closed  Expired
#                                          #MT-10334
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     44960 W Sandhill Rd
#     <br/>
#     Maricopa, AZ 85239
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 10/25/2007
#     <br/>
#     Expires: 11/28/2009
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abarca,
#                                         Adriana
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Closed  Expired
#                                          #MT-04249P
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     17031 N 11th Ave #2147
#     <br/>
#     Phoenix, AZ 85023
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 2/15/2005
#     <br/>
#     Expires: 8/25/2007
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abarca,
#                                         Jessica
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-15828
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     9557 W Quail ave
#     <br/>
#     Peoria, AZ 85382
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 6/13/2011
#     <br/>
#     Expires: 11/10/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abarca,
#                                         Maria
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-27094
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     6141 S Park Ave Unit 4
#     <br/>
#     Tucson, AZ 85706
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 9/8/2020
#     <br/>
#     Expires: 12/20/2022
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abarca,
#                                         Ricardo
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Closed  Expired
#                                          #MT-16760
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     6039 S 12th St
#     <br/>
#     Phoenix, AZ 85042
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 12/14/2011
#     <br/>
#     Expires: 10/3/2014
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abate,
#                                         Stephen
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-27557
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     14021 Villa Sandia PL NE
#     <br/>
#     Albuquerque, NM 87112
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 3/31/2021
#     <br/>
#     Expires: 4/4/2023
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#DCE4F1" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td bgcolor="#456198" colspan="2" height="1">
#   </td>
#  </tr>
#  <tr>
#   <td align="left" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     <strong>
#      Abbate,
#                                         Melissa
#     </strong>
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Active
#                                          #MT-14126
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     3510 East Hampton Avenue UNIT 20
#     <br/>
#     Mesa, AZ 85204
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#     Issued: 4/9/2010
#     <br/>
#     Expires: 4/24/2022
#     <br/>
#     <!--Status:&nbsp;Approved-->
#    </font>
#   </td>
#  </tr>
#  <tr>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#   <td align="right" bgcolor="#F7F9FD" valign="top">
#    <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    </font>
#   </td>
#  </tr>
# </table>

# %% [markdown]
# ### The `.get_text()` method of a `Tag` lets you access the text of all the children

# %% [markdown]
# Let's grab the second row of the table.
#
# You can see that the data is contained in two columns (`<td>` elements).

# %%
# select-second-row

# Select and display the second row of the data table.

second_row = inner_table.select("tr")[1]

print(second_row.prettify())
# Out:
# <tr>
#  <td align="left" bgcolor="#DCE4F1">
#   <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    <strong>
#     Ciuffardi,
#                                         Diana
#    </strong>
#   </font>
#  </td>
#  <td align="right" bgcolor="#DCE4F1">
#   <font face="Verdana, Arial, Helvetica, sans-serif" size="-1">
#    Active
#                                          #MT-26872
#   </font>
#  </td>
# </tr>

# %% [markdown]
# `second_row.get_text()` will show the text inside all the children of an element, without the HTML.

# %%
# display-second-row-text

# Display the text inside all elements

print(second_row.get_text())
# Out:
#                                          Ciuffardi,
#                                         Diana
#
#
#
#
#                                          Active
#                                          #MT-26872

# %% [markdown]
# Try to get the text inside the left-hand table cell `<td>` element, the one that contains the massage therapist's name.

# %%
# get-rhs-cell-text-blank

# Get and display the massage therapist's name.

# Try your solution here

# %% [markdown]
# ![](https://media.hswstatic.com/eyJidWNrZXQiOiJjb250ZW50Lmhzd3N0YXRpYy5jb20iLCJrZXkiOiJnaWZcL2phdmVsaW5hLmpwZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6ODI4fSwidG9Gb3JtYXQiOiJhdmlmIn19)

# %%
# get-rhs-cell-text

# Get and display the massage therapist's name.

print(second_row.select_one("td").get_text())
# Out:
#                                          Ciuffardi,
#                                         Diana

# %% [markdown]
# ## Step back: what makes this page tricky to scrape?
#
# Hint: Remember, HTML is hierarchical.

# %% [markdown]
# ![](https://i.pinimg.com/originals/ca/ea/99/caea991ceb006d69990be6e02ece6711.jpg)

# %% [markdown]
# Each massage therapist's record isn't contained in a parent element, instead, each piece of information is in a separate table row, with no structural relationship to related rows.
#
# Also, multiple pieces of information are contained inside the same element.
#
# This isn't an impossible situation, but it requires looking for other flags that we can use to detect when one record, or piece of information starts or ends.

# %% [markdown]
# ## Loops
#
# In this course, you've mostly worked with tabular data using Pandas. In many cases, Pandas allows manipulating data in a table without stepping through it row by row (Python programmers often use the term "iterating" or "iteration" to describe this).
#
# However, for programs that aren't transforming or aggregating tabular data, Python, and most other programming languages, have a featured called loops.
#
# The most frequently used loop in Python is the [for loop](https://realpython.com/python-for-loop/).
#
# It takes the basic form:
#
# ```
# for <var> in <list>:
#     # Do something with <var>
#     <statement(s)>
# ```
#
# Here's an example of a really simple for loop that prints Arizona county names:

# %%
# basic-for-loop-example

# Iterate over Arizona county names and display them

az_counties = [
    "Apache County",
    "Cochise County",
    "Coconino County",
    "Gila County",
    "Graham County",
    "Greenlee County",
    "La Paz County",
    "Maricopa County",
    "Mohave County",
    "Navajo County",
    "Pima County",
    "Pinal County",
    "Santa Cruz County",
    "Yavapai County",
    "Yuma County",
]

for county in az_counties:
    print(county)
# Out:
# Apache County
# Cochise County
# Coconino County
# Gila County
# Graham County
# Greenlee County
# La Paz County
# Maricopa County
# Mohave County
# Navajo County
# Pima County
# Pinal County
# Santa Cruz County
# Yavapai County
# Yuma County

# %% [markdown]
# ## If statements
#
# Another essential flow control feature of Python and most other languages are conditionals - a way to only execute code if some condition is met. Conditionals are written using `if`.
#
# If statements take the form:
#
# ```
# if <condition>:
#     # If the <condition> is met, do something
#     <statement(s)>
# ```
#
# Here's a really basic example where we modify the loop above to only print one county's name.

# %%
# basic-for-if-loop-example

# Iterate over Arizona county names and display only Maricopa's

az_counties = [
    "Apache County",
    "Cochise County",
    "Coconino County",
    "Gila County",
    "Graham County",
    "Greenlee County",
    "La Paz County",
    "Maricopa County",
    "Mohave County",
    "Navajo County",
    "Pima County",
    "Pinal County",
    "Santa Cruz County",
    "Yavapai County",
    "Yuma County",
]

for county in az_counties:
    if county == "Maricopa County":
        print(county)
# Out:
# Maricopa County

# %% [markdown]
# ## Putting it together
#
# Here's an example of using a `for` loop and an `if` statement to only print the names and license numbers of Active licenses.

# %%
# for-if-table-filter

# Only display text for active licenses

for tr in inner_table.select("tr"):
    row_text = tr.get_text().strip()
    
    if "Active" in row_text:
        print(row_text)
# Out:
# Ciuffardi,
#                                         Diana
#
#
#
#
#                                          Active
#                                          #MT-26872
# Giessman,
#                                         Marina
#
#
#
#
#                                          Active
#                                          #MT-26969
# Han,
#                                         Katherine
#
#
#
#
#                                          Active
#                                          #MT-28071
# Malaela,
#                                         Karalee
#
#
#
#
#                                          Active
#                                          #MT-21228
# Tovar,
#                                         Emily
#
#
#
#
#                                          Active
#                                          #MT-27882
# Urvanejo,
#                                         Ana
#
#
#
#
#                                          Active
#                                          #MT-27625
# Walker,
#                                         Michele
#
#
#
#
#                                          Active
#                                          #MT-27884
# Watkins,
#                                         Judith
#
#
#
#
#                                          Active
#                                          #MT-27966
# Aaron,
#                                         Cassandra
#
#
#
#
#                                          Active
#                                          #MT-14475
# Abad,
#                                         Cheryl
#
#
#
#
#                                          Active
#                                          #MT-02035P
# Abarca,
#                                         Jessica
#
#
#
#
#                                          Active
#                                          #MT-15828
# Abarca,
#                                         Maria
#
#
#
#
#                                          Active
#                                          #MT-27094
# Abate,
#                                         Stephen
#
#
#
#
#                                          Active
#                                          #MT-27557
# Abbate,
#                                         Melissa
#
#
#
#
#                                          Active
#                                          #MT-14126

# %% [markdown]
# ## Next steps
#
# ### More scraping learning and practice
#
# - NICAR tipsheets
#   - [asuozzo/nicar2022-python-scraping](https://github.com/asuozzo/nicar2022-python-scraping)
#   - [asuozzo/nicar2019-scraping](https://github.com/asuozzo/nicar2019-scraping)
#
# ### Using a real browser
#
# - [Playwright](https://playwright.dev/python/docs/intro)
# - [Selenium](https://selenium-python.readthedocs.io/)
#
# ### Really massive scrapers
#
# - [Scrapy](https://scrapy.org/)
#
# ### Scraping PDFs
#
# - [pdfplumber](https://github.com/jsvine/pdfplumber)

# %% [markdown]
# ## References
#
# - [Beautiful Soup Documentation](https://beautiful-soup-4.readthedocs.io/en/latest/)
# - [CSS selectors](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors)
# - [HTML elements reference](https://developer.mozilla.org/en-US/docs/Web/HTML/Element)
